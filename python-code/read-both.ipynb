# %%
import json
import datetime
import pandas as pd
import pyproj

data_file_a = open("data/location17062023_a.json")
data_file_b = open("data/location17062023_b.json")

def read_file(data_file):
    rows = {'datetime':[], 'numSat':[], 'lat':[], 'lon':[], 'alt':[], 'x':[], 'y':[], 'pdop':[], 'hdop':[], 'vdop':[], 'tdop':[]}
    trans = pyproj.Transformer.from_crs('WGS84', 'EPSG:3035')
    line : str
    for line in data_file:
        js = line.strip()
        if js:
            entry = json.loads(js)
            # print(entry)
            (hours, minutes, seconds) = entry['time'].split(':')
            (seconds, microseconds) = seconds.split('.')
            # Here both list comprehension [ op for x in list ] and unpack *[list] are used.
            # Expands to (year, month, day, hour, minute, second, microsecond, timezone)
            dt = datetime.datetime(*[int(i) for i in entry['date'].split('/')], *[int(i) for i in (hours, minutes, seconds, microseconds)], datetime.UTC)
            if entry['numSat'] > 11 and entry['tdop'] < 4.0:
                rows['datetime'].append(dt)
                rows['numSat'].append(entry['numSat'])
                rows['lat'].append(entry['lat'])
                rows['lon'].append(entry['lon'])
                rows['alt'].append(entry['alt'])
                rows['pdop'].append(entry['pdop'])
                rows['hdop'].append(entry['hdop'])
                rows['vdop'].append(entry['vdop'])
                rows['tdop'].append(entry['tdop'])
                x, y = trans.transform(float(entry['lon']), float(entry['lat']))
                rows['x'].append(x)
                rows['y'].append(y) 
    df = pd.DataFrame(rows)
    return df

if True:
    df = read_file(data_file_a)
    dfb =  read_file(data_file_b)
    x_mean = df['x'].mean()
    y_mean = df['y'].mean()
    alt_mean = df['alt'].mean()
    df['x'] = df['x'] - x_mean
    df['y'] = df['y'] - y_mean
    dfb['x'] = dfb['x'] - x_mean
    dfb['y'] = dfb['y'] - y_mean
    #df['z'] = alt_mean - df['alt'] 
    #df['s'] = (df['x']**2 + df['y']**2 + df['z']**2)**0.5
    #print("means", x, y)
    df.plot.scatter(x='x', y='y', c='datetime', s='numSat')

# %%
df.plot.line(x='datetime', y=['x'])
a_alt = df['alt'].values
b_alt = dfb['alt'].values
dfb.plot(ax=ax, x='datetime', y=['x'])
# Out:
# <Axes: xlabel='datetime'>

# %%
df.plot.line(x='datetime', y=['x'])
dfb.plot.line(x='datetime', y=['x'])
# Out:
# <Axes: xlabel='datetime'>

# %%
print("hello")
# Out:
# hello

# %%
df.plot.line(x='datetime', y=['pdop','hdop', 'vdop', 'tdop'])
# Out:
# <Axes: xlabel='datetime'>

# %%
df.plot.line(x='datetime', y=['x','y', 'z'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df.plot.line(x='datetime', y=['x','y', 'z'])
#
# File ~/.local/share/virtualenvs/spresense-projects-CmbopMN0/lib/python3.11/site-packages/pandas/plotting/_core.py:1044, in PlotAccessor.line(self, x, y, **kwargs)
#     979 @Appender(
#     980     """
#     981     See Also
#    (...)
#    1036 @Appender(_bar_or_line_doc)
#    1037 def line(self, x=None, y=None, **kwargs) -> PlotAccessor:
#    1038     """
#    1039     Plot Series or DataFrame as lines.
#    1040
#    1041     This function is useful to plot lines using DataFrame's values
#    1042     as coordinates.
#    1043     """
# -> 1044     return self(kind="line", x=x, y=y, **kwargs)
#
# File ~/.local/share/virtualenvs/spresense-projects-CmbopMN0/lib/python3.11/site-packages/pandas/plotting/_core.py:961, in PlotAccessor.__call__(self, *args, **kwargs)
#     958             pass
#     960 # don't overwrite
# --> 961 data = data[y].copy()
#     963 if isinstance(data, ABCSeries):
#     964     label_name = label_kw or y
#
# File ~/.local/share/virtualenvs/spresense-projects-CmbopMN0/lib/python3.11/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.local/share/virtualenvs/spresense-projects-CmbopMN0/lib/python3.11/site-packages/pandas/core/indexes/base.py:5876, in Index._get_indexer_strict(self, key, axis_name)
#    5873 else:
#    5874     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5876 self._raise_if_missing(keyarr, indexer, axis_name)
#    5878 keyarr = self.take(indexer)
#    5879 if isinstance(key, Index):
#    5880     # GH 42790 - Preserve name from an Index
#
# File ~/.local/share/virtualenvs/spresense-projects-CmbopMN0/lib/python3.11/site-packages/pandas/core/indexes/base.py:5938, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5935     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5937 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5938 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['z'] not in index"
